# %%
class centre:
    def service_centre(d):
        print("\t\t\t\t Fukra service centre")
        print("\t\t\t\t Since-1947")
        print("\t\t\t\t www.fukraservicecentre.com")
        print("\n\n\t\t\t\t\t services") 
        
    def services(d):
        x=["car","bike","bus"]
        for k in x:
            print("/n/n",k)
    
    def car(d):
        x=["Oil and filter","Air filter","Pcv value","Tire rotation and inspection","Tire balance","Wiper blades","Fuel filter replacement",]
        y=[650,1330,475,115,678,570,870]
        car_={"Car services":x,"Price":y}
        import pandas as pd 
        df=pd.DataFrame(car_)
        print("\n\n Car Services \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the Service : "))
            c=int(input("Enter the Quantity:"))
            z=car_["Price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder(yes/no):")
            if(x=="no"):
                print("Thank you for your order")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax = 5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupees")
        
    def bike(d):
        x=["valves","spark plug","carburetor","Air filter","Fuel Lines","Fuel filter","Engine Oil","Clutch","Wheels","Drive Chain","Battery"]
        y=[540,245,315,740,555,450,780,990,1150,1250,125]  
        bike_={"Bike service":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(bike_)
        print("\n\n Bike Service \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the Service  : "))
            c=int(input("Enter the Quantity:"))
            z=bike_["Price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder(yes/no):")
            if(x=="no"):
                print("Thank you for your order")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax = 5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupees")  
        
    def bus(d):
        x=["valves","spark plug","carburetor","Air filter","Fuel Lines","Fuel filter","Engine Oil","Clutch","Wheels","Drive Chain","Battery"]
        y=[540,245,315,740,555,450,780,990,1150,1250,125]  
        bike_={"Bike service":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(bike_)
        print("\n\n Bike Service \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("Enter the Service  : "))
            c=int(input("Enter the Quantity:"))
            z=bike_["Price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder(yes/no):")
            if(x=="no"):
                print("Thank you for your order")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax = 5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupees")

# %%
obj=centre()
obj.service_centre()
obj.services()
# Out:
# 				 Fukra service centre
# 				 Since-1947
# 				 www.fukraservicecentre.com
#
#
# 					 services
# /n/n car
# /n/n bike
# /n/n bus

# %%
x=input("Enter the Type of service : ")
if x=="car":
    print(obj.car())
elif x=="bike":
    print(obj.bike())
elif x=="bus":
    print(obj.bus())
else:
    print("wrong option: \nplease again choose the right option:")
# Out:
# Enter the Type of service : car
#
#
#  Car Services
#
#
#                    Car services  Price
# 0                Oil and filter    650
# 1                    Air filter   1330
# 2                     Pcv value    475
# 3  Tire rotation and inspection    115
# 4                  Tire balance    678
# 5                  Wiper blades    570
# 6       Fuel filter replacement    870
# Enter the Service : 1
# Enter the Quantity:2
# you want to reorder(yes/no):no
# Thank you for your order
# servicetax = 5%
# Total Amount: 2660 Rupees
# Total Amount Including Service Tax: 2793.0 Rupees
# None
